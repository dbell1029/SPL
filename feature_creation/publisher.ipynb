# %% [markdown]
# ## `Publisher` Data Dictionary (all features created by inner joining parts of `checkout_ph` and `collection` on `Publisher`)
# * **publisher_key**: Publisher name, the table's primary key.
# * **pub_tot_checkouts**: The total amount of checkouts per publisher. Created by grouping by publisher and doing a `count()`.
# * **pub_tot_books**: The total about of books per publisher. The total amount of checkouts per publisher. Created by grouping by publisher and doing a `CountDistinct()` on BibNum.
# * **pub_checkout_percentile**: The percentile of a publisher in regards to their total checkouts. Created by using the `percent_rank()` on pub_tot_checkouts.
# * **pub_books_percentile**: The percentile of a publisher in regards to their total books. Created by using the `percent_rank()` on pub_tot_books.

# %% [markdown]
# ## Creating features by Publisher

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import *
from pyspark.sql.window import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# creating datatables from the database tables
collection = spark.table("library.collection")

checkout = spark.sql('''
SELECT *, MONTH(CheckoutDateTime) Month, YEAR(CheckoutDateTime) Year
FROM library.checkout_ph
'''
)

dictionary = spark.sql("SELECT * FROM library.data_dictionary").toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## filtering checkout data to sept 2017 to sept 2019

# %%
checkout.filter("((Year = 2017 and Month >= 9) or (Year >= 2018)) and ((Year = 2019 and Month <= 9) or (year < 2019))")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: DataFrame[ID: string, CheckoutYear: bigint, BibNumber: bigint, ItemBarcode: string, ItemType: string, Collection: string, CallNumber: string, ItemTitle: string, Subjects: string, CheckoutDateTime: timestamp, Month: int, Year: int]</div>

# %%
df_print_books = dictionary.query("code_type == 'ItemType' and format_subgroup == 'Book' and format_group == 'Print'")
book_codes = df_print_books.code.to_list()
print(book_codes)

# display(df_print_books)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;arbk&#39;, &#39;ucunknj&#39;, &#39;bcbk&#39;, &#39;jrbk&#39;, &#39;jcbk&#39;, &#39;acbk&#39;, &#39;jrmus&#39;, &#39;pkbknh&#39;, &#39;ucunkn&#39;, &#39;jcmus&#39;, &#39;ahbk&#39;]
# </div>

# %%
books = collection \
  .withColumn('ReportDate', F.to_date(F.col("ReportDate"), "MM/dd/yyyy")) \
  .filter((F.col('ReportDate') >= F.lit("2017-09-01")) & (F.col('ReportDate') <= F.lit("2019-09-30")) & (F.col('ItemType').isin(book_codes)))
#display(books)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(checkout)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>CheckoutYear</th><th>BibNumber</th><th>ItemBarcode</th><th>ItemType</th><th>Collection</th><th>CallNumber</th><th>ItemTitle</th><th>Subjects</th><th>CheckoutDateTime</th></tr></thead><tbody><tr><td>201611051226000010077570322</td><td>2016</td><td>2866071</td><td>0010077570322</td><td>acbk</td><td>nanf</td><td>746.43204 V869 2012</td><td>Vogue Knitting the ultimate hat book history technique design</td><td>Knitting Patterns, Hats</td><td>2016-11-05T12:26:00.000+0000</td></tr><tr><td>201608021407000010084202216</td><td>2016</td><td>3068717</td><td>0010084202216</td><td>jcbk</td><td>ncfic</td><td>J GURTLER</td><td>Shyannas wish</td><td>Mermaids Juvenile fiction, Birthdays Juvenile fiction, Rescues Juvenile fiction, Friendship Juvenile fiction, Mermaids Fiction, Birthdays Fiction, Rescues Fiction, Friendship Fiction</td><td>2016-08-02T14:07:00.000+0000</td></tr><tr><td>201609251509000010086370375</td><td>2016</td><td>3086557</td><td>0010086370375</td><td>acbk</td><td>nafic</td><td>FIC RAEDER 2015</td><td>Black iris</td><td>Romantic suspense fiction</td><td>2016-09-25T15:09
><td>Green, Rod (Journalist)</td><td>1682971538, 9781682971536</td><td>[2017]</td><td>QEB,</td><td>Tractors Juvenile literature</td><td>jcbk</td><td>ncenf</td><td>null</td><td>bea</td><td>2019-07-01</td><td>1</td></tr><tr><td>3451550</td><td>The Parisian, or, Al-Barisi : a novel / Isabella Hammad.</td><td>Hammad, Isabella.</td><td>0802129439, 9780802129437</td><td>2019.</td><td>Grove Press,</td><td>Autonomy and independence movements Fiction, Middle East History Fiction, Nablus Fiction, Paris France Fiction, Bildungsromans, Historical fiction</td><td>acbk</td><td>nafic</td><td>null</td><td>wts</td><td>2019-07-01</td><td>1</td></tr><tr><td>3013518</td><td>My heart is laughing / written by Rose Lagercrantz ; illustrated by Eva Eriksson.</td><td>Lagercrantz, Rose, 1947-</td><td>1877579513, 1877579521, 9781877579516, 9781877579523</td><td>2014.</td><td>Gecko Press,</td><td>Bullying Juvenile fiction, Happiness Juvenile fiction, Schools Juvenile fiction</td><td>jcbk</td><td>ncef</td><td>null</td><td>swt</td><td>2019-07-01</td><td>1</td></tr><tr><td>2729577</td><td>All about acrylics : a complete guide to painting using this versatile medium / Oliver Löhr, Kristina Schaper and Ute Zander; with photographs by Stefan Boekels.</td><td>Löhr, Oliver</td><td>1844486052, 9781844486052</td><td>2011.</td><td>Search,</td><td>Acrylic painting Technique</td><td>acbk</td><td>nanf</td><td>null</td><td>nga</td><td>2019-07-01</td><td>1</td></tr><tr><td>2801859</td><td>The Obamians : the struggle inside the White House to redefined American power / James Mann.</td><td>Mann, Jim, 1946-</td><td>0670023760, 9780670023769</td><td>2012.</td><td>Viking,</td><td>Obama Barack, Obama Barack Political and social views, Obama Barack Friends and associates, Democratic Party U S History 21st century, Power Social sciences United States History 21st century, Presidents United States Biography, Politicians United States Biography, United States Foreign relations 2009, United States Military policy, United States Politics and government 2009</td><td>acbk</td><td>canf</td><td>null</td><td>cen</td><td>2019-07-01</td><td>1</td></tr><tr><td>3102735</td><td>Sensation Comics featuring Wonder Woman. Volume 1 / Gail Simone (and 10 others), writers ; Ethan Van Sciver (and 10 others), artists ; Brian Miller of Hi-Fi Colour Design (and 7 others), colorists ; Saida Temofonte, Deron Bennett, letterers ; Gene Ha Collection cover artist.</td><td>null</td><td>140125344X, 9781401253448</td><td>[2015]</td><td>DC Comics,</td><td>Wonder Woman Fictitious character Comic books strips etc, Women superheroes Comic books strips etc, Comic books strips etc United States, Graphic novels, Superhero comic books strips etc</td><td>acbk</td><td>nycomic</td><td>null</td><td>bal</td><td>2019-07-01</td><td>1</td></tr><tr><td>730418</td><td>Final report of the Ad Hoc Committee for a Central Area School Council / [Seattle Public Schools].</td><td>Ad Hoc Committee for a Central Area School Council.</td><td>null</td><td>[1969]</td><td>[The Committee],</td><td>Seattle Public Schools, Public schools Washington State Seattle Citizen participation, Community organization Washington State Seattle, Community and school Washington State Seattle, Citizens adv ...

# %%
checkout_join = checkout.select(checkout.BibNumber)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## creating my dataset with publisher to create features

# %%
# creating my dataset with publisher to create features
pub = books.join(checkout_join, checkout_join.BibNumber ==  books.BibNum, "inner") 

pub = pub.select(["BibNum", "Publisher", "PublicationYear", "Title"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(pub)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chkts_per_pub.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---------+
#            Publisher|    count|
# +--------------------+---------+
#          Dodd, Mead,|   162578|
#      Lakeside Press,|     1960|
# Congress on Resea...|      172|
#            Putnam&#39;s,|  7571909|
# British Library a...|      621|
# Hyperion Books fo...|222116902|
# Greenwillow Books...| 16901482|
#          Crown Pub.,|  1797101|
# Design Originals,...|    63962|
#        Namaste Pub.,|   102971|
# Chronicle Books LLC,|  8365513|
# Forever, an impri...|     1176|
#    Hisakatachairudo,|     8109|
# Simon Spotlight, ...|    34529|
# Book Division, Fa...|       18|
#            Doubleday|  4034836|
#    Avery Pub. Group,|     1641|
#       Phaidon Press,|  1060167|
# N. Yeh&#39;s Art Studio,|     2107|
# Andrews McMeel Pub.,|  8924712|
# +--------------------+---------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ##creating a total unique bib numbers by publisher in the SPL system column

# %%
# creating total books by publisher
books_per_pub = books.groupBy("Publisher").agg(countDistinct(col("BibNum")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## joining the two columns

# %%
# joining features into main dataset

publisher = chkts_per_pub.join(books_per_pub, ["Publisher"], "outer")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
publisher = publisher.withColumnRenamed("count", "total_checkouts")
publisher = publisher.withColumnRenamed("count(BibNum)", "total_books")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# replacing null's with 0's
publisher = publisher.na.fill(value=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## creating publisher rank in system in terms of checkout totals

# %%
windowSpec = Window \
.partitionBy() \
.orderBy(col("total_checkouts"))

publisher = publisher \
.withColumn("chkts_percent_rank", percent_rank().over(windowSpec))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## creating publisher rank in system in terms of bibnumber totals

# %%
windowSpec = Window \
.partitionBy() \
.orderBy(col("total_books"))



publisher = publisher \
.withColumn("books_percent_rank", percent_rank().over(windowSpec))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
publisher = publisher.withColumnRenamed("total_checkouts", "pub_tot_checkouts")
publisher = publisher.withColumnRenamed("total_books", "pub_tot_books")
publisher = publisher.withColumnRenamed("chkts_percent_rank", "pub_checkout_percentile")
publisher = publisher.withColumnRenamed("books_percent_rank", "pub_books_percentile")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
publisher = publisher.withColumnRenamed("Publisher", "publisher_key")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(publisher)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Publisher</th><th>pub_tot_checkouts</th><th>pub_tot_books</th><th>pub_checkout_percentile</th><th>pub_books_percentile</th></tr></thead><tbody><tr><td>null</td><td>857735</td><td>0</td><td>0.9926135858670643</td><td>0.0</td></tr><tr><td>"The Stage,"</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></tr><tr><td>"The Studio,",</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></tr><tr><td>"The Times",</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></tr><tr><td>1797 House,</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></tr><tr><td>A. Burdick,</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></tr><tr><td>A. Constable and Company, limited,</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></tr><tr><td>A. Hatier</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></tr><tr><td>A. L. Bancroft and Company,</td><td>0</td><td>1</td><td>0.0</td><td>9.874885204459498E-6</td></